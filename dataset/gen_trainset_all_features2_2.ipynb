# %%
import csv
import numpy as np
import os
import pandas as pd
import math
import datetime

# %%
df = pd.read_csv('trainset_all_features2.csv')

# %%
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'uId',
#  'age_group',
#  'bootTimes',
#  'AFuncTimes',
#  'BFuncTimes',
#  'CFuncTimes',
#  'DFuncTimes',
#  'EFuncTimes',
#  'FFuncTimes',
#  'FFuncSum',
#  'gender',
#  'prodName',
#  'ramCapacity',
#  'ramLeftRation',
#  'romCapacity',
#  'romLeftRation',
#  'fontSize',
#  'os',
#  'ct_2g',
#  'ct_2g#wifi',
#  'ct_3g',
#  'ct_3g#wifi',
#  'ct_4g',
#  'ct_4g#wifi',
#  'ct_wifi',
#  'carrier_China_Mobile',
#  'carrier_China_Telecom',
#  'carrier_China_Unicom',
#  'carrier_othercp',
#  'app_numbers',
#  'categery_0',
#  'categery_1',
#  'categery_2',
#  'categery_3',
#  'categery_4',
#  'categery_5',
#  'categery_6',
#  'categery_7',
#  'categery_8',
#  'categery_9',
#  'categery_10',
#  'categery_11',
#  'categery_12',
#  'categery_13',
#  'categery_14',
#  'categery_15',
#  'categery_16',
#  'categery_17',
#  'categery_18',
#  'categery_19',
#  'categery_20',
#  'categery_21',
#  'categery_22',
#  'categery_23',
#  'categery_24',
#  'categery_25',
# ...

# %%
import math

prod_counts = df['prodName'].value_counts()
# print(prod_counts)
print(len(prod_counts))
# len(prod_counts[prod_counts>=0])
# prod_counts.apply(lambda x: math.log10(x)).plot(kind='line', grid=True, label='S1',title='This is Series', style='--')
prod_counts.plot(kind='line', grid=True, label='S1',title='This is Series', style='--')
# Out:
# 127

# %%
n=3000
print(len(prod_counts[prod_counts<=n]))
prod_counts[prod_counts<=n].sum()/prod_counts.sum()
# Out:
# 61
# 0.03423346198530148

# %%
print(3000/prod_counts.sum())
# Out:
# 0.0021756251658914187

# %%
durations = [ 'weekdayDuration_0',
 'weekdayDuration_1',
 'weekdayDuration_2',
 'weekdayDuration_3',
 'weekdayDuration_4',
 'weekdayDuration_5',
 'weekdayDuration_6',
 'weekdayDuration_7',
 'weekdayDuration_8',
 'weekdayDuration_9',
 'weekdayDuration_10',
 'weekdayDuration_11',
 'weekdayDuration_12',
 'weekdayDuration_13',
 'weekdayDuration_14',
 'weekdayDuration_15',
 'weekdayDuration_16',
 'weekdayDuration_17',
 'weekdayDuration_18',
 'weekdayDuration_19',
 'weekdayDuration_20',
 'weekdayDuration_21',
 'weekdayDuration_22',
 'weekdayDuration_23',
 'weekdayDuration_24',
 'weekdayDuration_25',
 'weekdayDuration_26',
 'weekdayDuration_27',
 'weekdayDuration_28',
 'weekdayDuration_29',
 'weekdayDuration_30',
 'weekdayDuration_31',
 'weekdayDuration_32',
 'weekdayDuration_33',
 'weekdayDuration_34',
 'weekdayDuration_35',
 'weekdayDuration_36',
 'weekdayDuration_37',
 'weekdayDuration_38',
 'weekdayDuration_39',
 'weekdayDuration_40',
 'weekdayDuration_41',
 'weekdayDuration_42',
 'weekdayDuration_43',
 'weekdayDuration_44',
 'weekdayDuration_45',
 'weekdayDuration_46',
 'weekdayDuration_47',
 'weekdayDuration_48',
 'weekdayDuration_49',
 'weekdayDuration_50',
 'weekdayDuration_51',
 'weekdayDuration_52',
 'weekdayDuration_53',
 'weekdayDuration_54',
 'weekdayDuration_55',
 'weekdayDuration_56',
 'weekdayDuration_57',
 'weekdayDuration_58',
 'weekdayDuration_59',
 'weekdayDuration_60',
 'weekdayDuration_61',
 'weekdayDuration_62',
 'weekdayDuration_63',
 'weekdayDuration_64',
 'weekdayDuration_65',
 'weekdayDuration_66',
 'weekdayDuration_67',
 'weekdayDuration_68',
 'weekdayDuration_69',
 'weekdayDuration_70',
 'weekdayDuration_71',
 'weekdayDuration_72',
 'weekdayDuration_73',
 'weekdayDuration_74',
 'weekdayDuration_75',
 'weekdayDuration_76',
 'weekdayDuration_77',
 'weekdayDuration_78',
 'weekdayDuration_79',
 'weekdayDuration_80',
 'weekdayDuration_81',
 'weekdayDuration_82',
 'weekdayDuration_83',
 'weekdayDuration_84',
 'weekdayDuration_85',
 'weekdayDuration_86',
 'weekdayDuration_87',
 'weekdayDuration_88',
 'weekdayDuration_89',
 'weekdayDuration_90',
 'weekdayDuration_91',
 'weekdayDuration_92',
 'weekdayDuration_93',
 'weekdayDuration_94',
 'weekdayDuration_95',
 'weekdayDuration_96',
 'weekdayDuration_97',
 'weekdayDuration_98',
 'weekdayDuration_99',
 'weekendDuration_0',
 'weekendDuration_1',
 'weekendDuration_2',
 'weekendDuration_3',
 'weekendDuration_4',
 'weekendDuration_5',
 'weekendDuration_6',
 'weekendDuration_7',
 'weekendDuration_8',
 'weekendDuration_9',
 'weekendDuration_10',
 'weekendDuration_11',
 'weekendDuration_12',
 'weekendDuration_13',
 'weekendDuration_14',
 'weekendDuration_15',
 'weekendDuration_16',
 'weekendDuration_17',
 'weekendDuration_18',
 'weekendDuration_19',
 'weekendDuration_20',
 'weekendDuration_21',
 'weekendDuration_22',
 'weekendDuration_23',
 'weekendDuration_24',
 'weekendDuration_25',
 'weekendDuration_26',
 'weekendDuration_27',
 'weekendDuration_28',
 'weekendDuration_29',
 'weekendDuration_30',
 'weekendDuration_31',
 'weekendDuration_32',
 'weekendDuration_33',
 'weekendDuration_34',
 'weekendDuration_35',
 'weekendDuration_36',
 'weekendDuration_37',
 'weekendDuration_38',
 'weekendDuration_39',
 'weekendDuration_40',
 'weekendDuration_41',
 'weekendDuration_42',
 'weekendDuration_43',
 'weekendDuration_44',
 'weekendDuration_45',
 'weekendDuration_46',
 'weekendDuration_47',
 'weekendDuration_48',
 'weekendDuration_49',
 'weekendDuration_50',
 'weekendDuration_51',
 'weekendDuration_52',
 'weekendDuration_53',
 'weekendDuration_54',
 'weekendDuration_55',
 'weekendDuration_56',
 'weekendDuration_57',
 'weekendDuration_58',
 'weekendDuration_59',
 'weekendDuration_60',
 'weekendDuration_61',
 'weekendDuration_62',
 'weekendDuration_63',
 'weekendDuration_64',
 'weekendDuration_65',
 'weekendDuration_66',
 'weekendDuration_67',
 'weekendDuration_68',
 'weekendDuration_69',
 'weekendDuration_70',
 'weekendDuration_71',
 'weekendDuration_72',
 'weekendDuration_73',
 'weekendDuration_74',
 'weekendDuration_75',
 'weekendDuration_76',
 'weekendDuration_77',
 'weekendDuration_78',
 'weekendDuration_79',
 'weekendDuration_80',
 'weekendDuration_81',
 'weekendDuration_82',
 'weekendDuration_83',
 'weekendDuration_84',
 'weekendDuration_85',
 'weekendDuration_86',
 'weekendDuration_87',
 'weekendDuration_88',
 'weekendDuration_89',
 'weekendDuration_90',
 'weekendDuration_91',
 'weekendDuration_92',
 'weekendDuration_93',
 'weekendDuration_94',
 'weekendDuration_95',
 'weekendDuration_96',
 'weekendDuration_97',
 'weekendDuration_98',
 'weekendDuration_99',]

# %%
print(len(['prodName_p001',
 'prodName_p0010',
 'prodName_p00100',
 'prodName_p00102',
 'prodName_p00103',
 'prodName_p00104',
 'prodName_p00105',
 'prodName_p00106',
 'prodName_p00107',
 'prodName_p00108',
 'prodName_p0011',
 'prodName_p00110',
 'prodName_p00111',
 'prodName_p00112',
 'prodName_p00113',
 'prodName_p00120',
 'prodName_p00121',
 'prodName_p00122',
 'prodName_p00123',
 'prodName_p00124',
 'prodName_p00127',
 'prodName_p00128',
 'prodName_p00129',
 'prodName_p0013',
 'prodName_p00130',
 'prodName_p00131',
 'prodName_p00133',
 'prodName_p00136',
 'prodName_p00137',
 'prodName_p00139',
 'prodName_p0014',
 'prodName_p00141',
 'prodName_p00142',
 'prodName_p00143',
 'prodName_p00144',
 'prodName_p00145',
 'prodName_p00146',
 'prodName_p00147',
 'prodName_p0015',
 'prodName_p00153',
 'prodName_p00155',
 'prodName_p00156',
 'prodName_p00157',
 'prodName_p00158',
 'prodName_p00159',
 'prodName_p0016',
 'prodName_p00164',
 'prodName_p00165',
 'prodName_p00166',
 'prodName_p00168',
 'prodName_p00169',
 'prodName_p0017',
 'prodName_p00171',
 'prodName_p00176',
 'prodName_p0018',
 'prodName_p0019',
 'prodName_p00197',
 'prodName_p00198',
 'prodName_p00199',
 'prodName_p002',
 'prodName_p00200',
 'prodName_p00201',
 'prodName_p00202',
 'prodName_p00203',
 'prodName_p00204',
 'prodName_p00205',
 'prodName_p00206',
 'prodName_p00207',
 'prodName_p00208',
 'prodName_p00209',
 'prodName_p00210',
 'prodName_p00211',
 'prodName_p00212',
 'prodName_p00213',
 'prodName_p00214',
 'prodName_p00216',
 'prodName_p00217',
 'prodName_p0022',
 'prodName_p00220',
 'prodName_p00221',
 'prodName_p00222',
 'prodName_p00223',
 'prodName_p00224',
 'prodName_p00225',
 'prodName_p00226',
 'prodName_p0023',
 'prodName_p0024',
 'prodName_p0025',
 'prodName_p0026',
 'prodName_p0027',
 'prodName_p0028',
 'prodName_p0029',
 'prodName_p0030',
 'prodName_p0031',
 'prodName_p0032',
 'prodName_p0033',
 'prodName_p0035',
 'prodName_p0036',
 'prodName_p0037',
 'prodName_p0038',
 'prodName_p0039',
 'prodName_p0040',
 'prodName_p0041',
 'prodName_p0043',
 'prodName_p0044',
 'prodName_p0045',
 'prodName_p0046',
 'prodName_p0047',
 'prodName_p0048',
 'prodName_p0050',
 'prodName_p0051',
 'prodName_p0052',
 'prodName_p0053',
 'prodName_p0054',
 'prodName_p0055',
 'prodName_p006',
 'prodName_p0063',
 'prodName_p007',
 'prodName_p0079',
 'prodName_p0081',
 'prodName_p0082',
 'prodName_p0088',
 'prodName_p0089',
 'prodName_p009',
 'prodName_p0095',
 'prodName_p0096',
 'prodName_p0097',
 'prodName_p0098',
 'prodName_p0099',]))
# Out:
# 129

# %%
df.drop(durations,axis=1,inplace=True)
df.info()

# %%
fontSize_counts =  df['fontSize'].value_counts()
# print(type(fontSize_counts))
most_fontSize = fontSize_counts.iloc[0:5]
# print(most_fontSize)
most_fontSize_value = most_fontSize.index
print(most_fontSize_value)

# %%
df.fontSize[-(df['fontSize'].isin(most_fontSize_value))] = 0
print(df.info())
df['fontSize'].value_counts()

# %%
prod_counts = df['prodName'].value_counts()
most_prodName = prod_counts[prod_counts>=3000].index
print(most_prodName)

# %%
df.prodName[-(df['prodName'].isin(most_prodName))] = 0
print(df.info())
df['prodName'].value_counts()

# %%
df = pd.get_dummies(df,columns=['prodName','fontSize'])
df.info()
print(len(df.columns))
print(df.columns)

# %%
list(df.columns)

# %%
ll = [ 'ramCapacity','ramLeftRation','romCapacity','romLeftRation','weekdayTimesSum','weekendTimesSum', 'rate2', 'weekdayDurationSum',
 'weekendDurationSum','rate1']

# %%
for each in ll:
    df[each] = pd.cut(df[each], bins=5, labels=['a', 'b', 'c', 'd', 'e'])
print(df[['ramCapacity']])
# df = pd.get_dummies(df)

# %%
df = pd.get_dummies(df)

# %%
df.info()
print(len(df.columns))

# %%
list(df.columns)

# %%
df.to_csv('trainset_all_features2_2.csv')
